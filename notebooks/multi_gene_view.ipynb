# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
import celldega as dega

# %% [markdown]
# ### Inputs

# %%
gene_list = ['A2ML1','AAMP', 'MLANA', 'EPCAM']
path_landscape_files = "data/xenium_landscape_files/Xenium_Prime_Human_Skin_FFPE_outs"

# %%
wedges_gdf = dega.nbhd.multi_gene_visualization_processing(path_landscape_files=path_landscape_files, gene_list=gene_list, technology="Xenium", segmentation_approach="default")
wedges_gdf
# Out:
#             hex_id   gene  intensity  normalized  wedge_index  \
# 0     1050_polygon  A2ML1        0.0         0.0            0
# 1     1050_polygon   AAMP        0.0         0.0            1
# 2     1050_polygon  MLANA        1.0         1.0            2
# 3     1050_polygon  EPCAM        0.0         0.0            3
# 4     1061_polygon  A2ML1        0.0         0.0            0
# ...            ...    ...        ...         ...          ...
# 8699   992_polygon  EPCAM        0.0         0.0            3
# 8700   993_polygon  A2ML1        0.0         0.0            0
# 8701   993_polygon   AAMP        3.0         0.6            1
# 8702   993_polygon  MLANA        2.0         0.4            2
# 8703   993_polygon  EPCAM        0.0         0.0            3
#
#                                                geometry
# 0     POLYGON ((5106.836 796.875, 5106.137 788.887, ...
# 1     POLYGON ((5060.836 842.875, 5068.824 842.176, ...
# ...
