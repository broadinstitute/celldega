# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
import celldega as dega

# %% [markdown]
# ### Inputs

# %%
path_landscape_files="data/xenium_landscape_files/Xenium_Prime_Human_Skin_FFPE_outs"
hexatile_radius = 250

# %% [markdown]
# ### Create Hexatiles

# %%
gdf_hexatile = dega.nbhd.create_hexatile(radius=hexatile_radius, path_landscape_files=path_landscape_files)

# %% [markdown]
# ### Create a tiled view of hexatile-specific assigned transcripts using "default segmentation data"

# %%
path_data="data/Xenium_Prime_Human_Skin_FFPE_outs"

dega.nbhd.unassigned_transcripts_tiled_view(gdf_hexatile=gdf_hexatile, path_data=path_data, 
                                  path_landscape_files=path_landscape_files)
# Out:
# Reading transcripts file...
# Transcripts file read.
# Assignment of transcripts started...
# Assignment of transcripts done and saved.
# Calculating percentage of hexatile-specific unassigned transcripts...
# Calculation done, plotting a tiled view of hexatile-specific unassigned transcripts...
# Done.

# %% [markdown]
# ### Create a tiled view of hexatile-specific assigned transcripts using "custom segmentation data"

# %%
path_data="data/processed_data/xenium_skin/cellpose2"

dega.nbhd.unassigned_transcripts_tiled_view(gdf_hexatile=gdf_hexatile, path_data=path_data, 
                                  path_landscape_files=path_landscape_files)
# Out:
# Reading transcripts file...
# Transcripts file read.
# Assignment of transcripts started...
# Assignment of transcripts done and saved.
# Calculating percentage of hexatile-specific unassigned transcripts...
# Calculation done, plotting a tiled view of hexatile-specific unassigned transcripts...
# Done.

# %% [markdown]
# ### Create a tiled view of hexatile-specific assigned transcripts using "merged segmentation data (default + custom)"

# %%
path_data="data/processed_data/xenium_skin/cellpose2_xenium_default_merged"

dega.nbhd.unassigned_transcripts_tiled_view(gdf_hexatile=gdf_hexatile, path_data=path_data, 
                                  path_landscape_files=path_landscape_files)
# Out:
# Reading transcripts file...
# Transcripts file read.
# Assignment of transcripts started...
# Assignment of transcripts done and saved.
# Calculating percentage of hexatile-specific unassigned transcripts...
# Calculation done, plotting a tiled view of hexatile-specific unassigned transcripts...
# Done.
