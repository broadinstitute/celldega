# %%
import celldega as dega

# %%
path_default_data="data/Xenium_Prime_Human_Skin_FFPE_outs"
path_landscape_files="data/xenium_landscape_files/Xenium_Prime_Human_Skin_FFPE_outs"
hexatile_radius = 250

# %% [markdown]
# ### Create hexatile

# %%
gdf_hexatile = dega.nbhd.create_hexatile(radius=hexatile_radius, path_default_data=path_default_data, path_landscape_files=path_landscape_files)

# %% [markdown]
# ### Create a tiled view of hexatile-specific assigned transcripts

# %%
dega.nbhd.unassigned_transcripts_tiled_view(gdf_hexatile=gdf_hexatile, path_default_data=path_default_data, 
                                  path_landscape_files=path_landscape_files)
# Out:
# Reading transcripts file...
# Transcripts file read.
# Assignment of transcripts started...
# Assignment of transcripts done and saved.
# Calculating percentage of hexatile-specific unassigned transcripts...
# Calculation done, plotting a tiled view of hexatile-specific unassigned transcripts...
# Done.
