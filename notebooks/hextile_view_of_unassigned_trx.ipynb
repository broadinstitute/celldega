# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
import celldega as dega

# %% [markdown]
# ### Inputs

# %%
path_landscape_files="data/xenium_landscape_files/Xenium_Prime_Human_Skin_FFPE_outs"
hextile_radius = 250

# %% [markdown]
# ### Create Hexatiles

# %%
gdf_hextile = dega.nbhd.create_hextile(radius=hextile_radius, path_landscape_files=path_landscape_files, pixel_size=0.2125)
# Out:
# Hextiles saved at 'data/xenium_landscape_files/Xenium_Prime_Human_Skin_FFPE_outs' as 'hextiles.parquet'

# %% [markdown]
# ### Create a tiled view of hexatile-specific unassigned transcripts using "default segmentation data"

# %%
path_data="data/Xenium_Prime_Human_Skin_FFPE_outs"

hextile_assigned_trx, hextile_meta = dega.nbhd.hexatile_specific_unassigned_transcripts(gdf_hextile=gdf_hextile, path_data=path_data, 
                                  path_landscape_files=path_landscape_files)

dega.nbhd.plot_hexatile_specific_unassigned_transcripts(hextile_meta)
# Out:
# Reading transcripts file...
# Transcripts file read.
# Assignment of transcripts started...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 path_data="data/Xenium_Prime_Human_Skin_FFPE_outs"
# ----> 3 hextile_assigned_trx, hextile_meta = dega.nbhd.hexatile_specific_unassigned_transcripts(gdf_hextile=gdf_hextile, path_data=path_data,
#       4                                   path_landscape_files=path_landscape_files)
#       6 dega.nbhd.plot_hexatile_specific_unassigned_transcripts(hextile_meta)
#
# File ~/Documents/celldega/src/celldega/nbhd/__init__.py:451, in hexatile_specific_unassigned_transcripts(gdf_hextile, gdf_transcripts, path_data, path_landscape_files, percentage_unassigned_threshold)
#     446 gdf_hextile_assigned_trx.set_geometry("geometry", inplace=True)
#     448 if technology != "PYTEST":
#     450     gdf_hextile_assigned_trx.to_parquet(
# --> 451     os.path.join(
#     452         path_landscape_files,
#     453         f"hextile_assigned_trx_{technology}_{segmentation_approach}.parquet", engine="pyarrow")
#     454     )
#     456 print("Assignment of transcripts done and saved.")
#     458 print("Calculating percentage of hextile-specific unassigned transcripts...")
#
# TypeError: join() got an unexpected keyword argument 'engine'

# %% [markdown]
# ### Create a tiled view of hexatile-specific unassigned transcripts using "custom segmentation data"

# %%
path_data="data/processed_data/xenium_skin/cellpose2"

hextile_assigned_trx, hextile_meta = dega.nbhd.hexatile_specific_unassigned_transcripts(gdf_hextile=gdf_hextile, path_data=path_data, 
                                  path_landscape_files=path_landscape_files)

dega.nbhd.plot_hexatile_specific_unassigned_transcripts(hextile_meta)

# %% [markdown]
# ### Create a tiled view of hexatile-specific unassigned transcripts using "merged segmentation data (default + custom)"

# %%
path_data="data/processed_data/xenium_skin/cellpose2_xenium_default_merged"

hextile_assigned_trx, hextile_meta = dega.nbhd.hexatile_specific_unassigned_transcripts(gdf_hextile=gdf_hextile, path_data=path_data, 
                                  path_landscape_files=path_landscape_files)

dega.nbhd.plot_hexatile_specific_unassigned_transcripts(hextile_meta)
