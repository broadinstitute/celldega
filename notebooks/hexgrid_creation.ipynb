# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
import celldega as dega

# %% [markdown]
# ### Inputs

# %%
path_landscape_files="data/xenium_landscape_files/Xenium_Prime_Human_Skin_FFPE_outs"
hexatile_radius = 250

# %% [markdown]
# ### Create Hexatiles

# %%
gdf_hexatile = dega.nbhd.create_hextile(radius=hexatile_radius, path_landscape_files=path_landscape_files)
