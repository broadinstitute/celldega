# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1

# %%
import celldega as dega
import pandas as pd
import scanpy as sc

# %%
base_url = 'https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_V1_Human_Colon_Cancer_P1_CRC_Add_on_FFPE_outs/main/Xenium_V1_Human_Colon_Cancer_P1_CRC_Add_on_FFPE_outs'

# %% [markdown]
# # Load a Landscape with no pre-loaded neighborhoods and draw some example neighborhoods

# %%
landscape = dega.viz.Landscape(
    technology='Xenium',
    base_url = base_url,
    height=500,
    nbhd_edit=True
)

# %%
landscape

# %%
nbhd = landscape.nbhd

# %%
nbhd.plot()

# %%
nbhd.to_parquet('data/xenium_data/nbhd.parquet')

# %%
import geopandas as gpd

# %%
nbhd_from_disk = gpd.read_parquet('data/xenium_data/nbhd.parquet')

# %%
nbhd_from_disk

# %%
nbhd_from_disk.plot()

# %% [markdown]
# # Load a Landscape with pre-calculated neighborhoods and edit these neighborhoods and draw new neighborhoods

# %%
landscape_2 = dega.viz.Landscape(
    technology='Xenium',
    base_url = base_url,
    height=500,
    nbhd=nbhd_from_disk,
    nbhd_edit=True
)
landscape_2

# %%
nbhd_modify = landscape_2.nbhd

# %%
nbhd_modify.plot()
