# %% [markdown]
# # Landscape View Xenium

# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
import pandas as pd
import celldega as dega
# Out:
# /Users/feni/Documents/celldega/dega/lib/python3.12/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.5 when it was built against 1.14.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
base_url = 'https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Human_Skin_FFPE_outs/main/Xenium_Prime_Human_Skin_FFPE_outs'

# %%
landscape = dega.viz.Landscape(
    technology='Xenium',
    base_url = base_url,
    height=500,
    nbhd_edit=True
)
landscape
# Out:
# /var/folders/8d/jxpy9rd10j7fp2rcj_s5sz3c0000gq/T/ipykernel_16155/1696644676.py:1: UserWarning: Transformation matrix not found at https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Human_Skin_FFPE_outs/main/Xenium_Prime_Human_Skin_FFPE_outs/micron_to_image_transform.csv. Using identity.
#   landscape = dega.viz.Landscape(
# Landscape(base_url='https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Human_Skin_FFPE_out…

# %%
landscape.nbhd.plot()
# Out:
# <Axes: >
