# %% [markdown]
# # Yearbook Query

# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
import celldega as dega

# %%
base_url = 'https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs/main/Xenium_V1_Human_Colon_Cancer_P2_CRC_Add_on_FFPE_outs'

# %%
dega.viz.Landscape(
    technology='Xenium', 
    base_url = base_url
)
# Out:
# Landscape(base_url='https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_V1_Human_Colon_Cancer_P2_…

# %%
yb = dega.viz.Yearbook(
    base_url=base_url,
    rows=3,
    cols=6,
    portrait_size_um=20
)
yb
# Out:
# Yearbook(base_url='https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_V1_Human_Colon_Cancer_P2_C…
