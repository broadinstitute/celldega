# %% [markdown]
# # Landscape-Heatmap Xenium

# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
import pandas as pd
import celldega as dega

# %% [markdown]
# # iST Landscape View

# %%
base_url = 'https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Human_Skin_FFPE_outs/main/Xenium_Prime_Human_Skin_FFPE_outs'

# %%
landscape_ist = dega.viz.Landscape(
    technology='Xenium',
    base_url = base_url,
    height=600,
)
# Out:
# /var/folders/8d/jxpy9rd10j7fp2rcj_s5sz3c0000gq/T/ipykernel_92392/1886176030.py:1: UserWarning: Transformation matrix not found at https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Human_Skin_FFPE_outs/main/Xenium_Prime_Human_Skin_FFPE_outs/micron_to_image_transform.csv. Using identity.
#   landscape_ist = dega.viz.Landscape(

# %%
file_path = 'https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Human_Skin_FFPE_outs/main/Xenium_Prime_Human_Skin_FFPE_outs/df_sig.parquet'
df_sig = pd.read_parquet(file_path)
mat = dega.clust.Matrix(data=df_sig)
mat.norm(axis='row', by='zscore')
mat.cluster()
cgm = dega.viz.Clustergram(matrix=mat, width=500, height=500)

# %%
dega.viz.landscape_clustergram(landscape_ist, cgm)
# Out:
# HBox(children=(Landscape(base_url='https://raw.githubusercontent.com/broadinstitute/celldega_Xenium_Prime_Huma…
