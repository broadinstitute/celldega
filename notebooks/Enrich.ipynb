# %% [markdown]
# # Enrich
# Using the viz.Enrich Enrichr API and visualization. Front-end adapted from https://observablehq.com/@ismms-himc/covid-19-transcriptional-signature-tenoever-data-a549.

# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
import celldega as dega

# %%
gene_list = [
  'CD19', 'CD20', 'MS4A1', 'CD79A', 'CD79B',
  'PAX5', 'EBF1', 'SPIB', 'BLNK', 'BANK1',
  'BTK', 'SYK', 'LYN', 'BLK', 'PIK3CD',
  'IRF4', 'IRF8', 'BCL6', 'PRDM1', 'XBP1',
  'TNFRSF13C', 'TNFRSF17', 'CD38', 'CD27', 'MZB1',
  'AICDA', 'UNF', 'TNFSF13B', 'IKZF1', 'IKZF3',
  'IL4R', 'CXCR5', 'CCR6', 'CXCL13', 'CR2',
  'FCGR2B', 'FCRL5', 'MEF2C', 'IGHM', 'IGHD',
  'IGHG1', 'IGHG2', 'IGHA1', 'IGHA2', 'IGKC',
  'JCHAIN', 'LAMC2', 'CD24', 'CD40', 'BACH2',
  'TCL1A', 'HLA-DRA', 'HLA-DRB1', 'HLA-DQA1', 'HLA-DQB1'
]

# %%
short_gene_list = [
  'CD19', 'CD20', 'MS4A1', 'CD79A', 'CD79B',
]

# %%
enr = dega.viz.Enrich(gene_list=gene_list)
enr

# %%
# enr.gene_list = short_gene_list
